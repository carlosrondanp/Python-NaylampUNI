# %% [markdown]
# # Numpy
#
# Es un módulo que nos ayudará a trabajar con arrays (como listas), per más rápidas de procesar

# %%
import numpy as np

# %% [markdown]
# ## Crear un array a partir de una lista

# %%
a = np.array([1,2,3,4])
print(a)
# Out:
# [1 2 3 4]

# %%
type(a)
# Out:
# numpy.ndarray

# %% [markdown]
# ## Crear un array a partir de una tupla

# %%
b = np.array((1,2,3))
print(b)
# Out:
# [1 2 3]

# %% [markdown]
# ## Dimensiones de un array

# %%
unidimensional = np.array([1,2,3,4,5])
unidimensional
# Out:
# array([1, 2, 3, 4, 5])

# %%
unidimensional.ndim
# Out:
# 1

# %%
bidimensional = np.array([[1,2,3],
                          [4,5,6]])
bidimensional
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
bidimensional.ndim
# Out:
# 2

# %%
tridimensional = np.array([[[1,2,3], 
                            [4,5,6]], 
                           
                           [[1,2,3],
                            [4,5,6]] ])
tridimensional
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])

# %%
tridimensional.ndim
# Out:
# 3

# %% [markdown]
# ## Acceder a los elementos de un array

# %%
unidimensional[2]
# Out:
# 3

# %%
bidimensional[0][2], bidimensional[0,2]
# Out:
# (3, 3)

# %%
tridimensional[1,0,2]
# Out:
# 3

# %% [markdown]
# ## filtrar arrays

# %%
tridimensional
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])

# %%
tridimensional[tridimensional%2 == 0]
# Out:
# array([2, 4, 6, 2, 4, 6])

# %% [markdown]
# ## shape: número de elementos de cada dimensión

# %%
unidimensional
# Out:
# array([1, 2, 3, 4, 5])

# %%
unidimensional.shape
# Out:
# (5,)

# %%
bidimensional
# Out:
# array([[1, 2, 3],
#        [4, 5, 6]])

# %%
bidimensional.shape
# Out:
# (2, 3)

# %%
tridimensional
# Out:
# array([[[1, 2, 3],
#         [4, 5, 6]],
#
#        [[1, 2, 3],
#         [4, 5, 6]]])

# %%
tridimensional.shape
# Out:
# (2, 2, 3)

# %%
tridimensional.reshape(3,2,2)
# Out:
# array([[[1, 2],
#         [3, 4]],
#
#        [[5, 6],
#         [1, 2]],
#
#        [[3, 4],
#         [5, 6]]])

# %% [markdown]
# ## Operaciones

# %%
a = np.array([2,4,5,1])
b = np.array([1,3,2,5])

c = [2,4,5,1]
d = [1,3,2,5]

# %%
a + b
# Out:
# array([3, 7, 7, 6])

# %%
c + d
# Out:
# [2, 4, 5, 1, 1, 3, 2, 5]

# %%
a - b
# Out:
# array([ 1,  1,  3, -4])

# %%
a * b
# Out:
# array([ 2, 12, 10,  5])

# %%
a/ b
# Out:
# array([2.        , 1.33333333, 2.5       , 0.2       ])

# %% [markdown]
# ## Ejemplito

# %% [markdown]
# Realizar una función que tenga como salida la probabilidad ($P_i$) y como parámetros $x$ y $\beta$
#
# $$
# P_i = P(x_i) = \frac{1}{1+e^{-\displaystyle\sum_{j=0}^{k}\beta_j \cdot x_{ij}}}
# $$
#
# La probabilidad que estamos calculando es la probabilidad para cada observación dentro deun registro (i : filas)
#
# Partiremos del siguiente dataframe, para evaluar posteriormente
#
# |x_1|x_2|
# |-|-|
# |1|5|
# |1|4|
# |5|1|
#
# y $\beta = \begin{bmatrix}
# 	5  \\
# 	4  \\
# 	\end{bmatrix}$
#
# Entonces Para $P_0$ tendríamos lo siguiente:
# $x_{0j} = \begin{bmatrix}
# 	1 & 5 \\
# 	\end{bmatrix}$
# $$
# P_0 = P(x_0) = \frac{1}{1+e^{-\displaystyle\sum^{1}_{j=0}\beta_j \cdot x_{0j} }}\\
# P_0 = \displaystyle\frac{1}{1+e^{-1(\beta_0 \cdot x_{00} + \beta_1 \cdot x_{01}) } } = \displaystyle\frac{1}{1+e^{-(5*1 + 4*5)} }\\
# P_0 = \frac{1}{1+e^{-25}} = 0.999999999986112
# $$
#
# Entonces Para $P_1$ tendríamos lo siguiente:
# $x_{1j} = \begin{bmatrix}
# 	1 & 4 \\
# 	\end{bmatrix}$
# $$
# P_1 = P(x_1) = \frac{1}{1+e^{-\displaystyle\sum^{1}_{j=0}\beta_j \cdot x_{0j} }}\\
# P_1 = \displaystyle\frac{1}{1+e^{-1(\beta_0 \cdot x_{10} + \beta_1 \cdot x_{11}) } } = \displaystyle\frac{1}{1+e^{-(5*1 + 4*4)} }\\
# P_1 = \frac{1}{1+e^{-21}} = 0.9999999992417439
# $$
#
# Entonces Para $P_2$ tendríamos lo siguiente:
# $x_{2j} = \begin{bmatrix}
# 	5 & 1 \\
# 	\end{bmatrix}$
# $$
# P_2 = P(x_2) = \frac{1}{1+e^{-\displaystyle\sum^{1}_{j=0}\beta_j \cdot x_{0j} }}\\
# P_2 = \displaystyle\frac{1}{1+e^{-1(\beta_0 \cdot x_{10} + \beta_1 \cdot x_{11}) } } = \displaystyle\frac{1}{1+e^{-(5*5 + 4*1)} }\\
# P_2 = \frac{1}{1+e^{-29}} = 0.9999999999997455
# $$

# %%
def probabilidad(X, beta):
    import numpy as np
    n_filas = np.shape(X)[0] # extraemos el número de filas del registro X 
    n_columnas = np.shape(X)[1] #extraemos el número de columnas del registro X
    pi = list(range(1,n_filas+1))
    expon = list(range(1,n_filas+1))
    for i in range(n_filas):
        expon[i] = 0 
        for j in range(n_columnas):
            ex = X[i][j] * beta[j]
            expon[i] = ex + expon[i]
            pi[i] = 1/(1+np.exp(-expon[i]))
            
    return pi

# %%
matriz = np.array([[1,5],
                   [1,4],
                   [5,1]])
beta = np.array([5,4])

# %%
probabilidad(matriz, beta)
# Out:
# [0.999999999986112, 0.9999999992417439, 0.9999999999997455]

# %% [markdown]
# # Dataframes
# **Dataframe:** Estructura bidimensional donde las filas son registros y las columnas son las variables

# %%
import pandas as pd

# %% [markdown]
# ## Convertir de diccionario a dataframe

# %%
diccionario = {'variable_1': [20,30,40,10,50],
               'variable_2': [2,4,5,6,7]}
df_1 = pd.DataFrame(diccionario)
df_1
# Out:
#    variable_1  variable_2
# 0          20           2
# 1          30           4
# 2          40           5
# 3          10           6
# 4          50           7

# %% [markdown]
# ## Covnertir de lista a dataframe

# %%
nombre_columnas = ['ID','Precio','Cantidad']
matriz = [['XC01', 2000,3],
          ['XC02', 3000, 2],
          ['XC03', 10000,4]]

# %%
df_2 = pd.DataFrame(data = matriz,
                    columns = nombre_columnas,
                    index = ['Propiedad ' + str(i+1) for i in range(df_2.shape[0])])
df_2
# Out:
#                ID  Precio  Cantidad
# Propiedad 1  XC01    2000         3
# Propiedad 2  XC02    3000         2
# Propiedad 3  XC03   10000         4

# %%
df_2.shape[0]
# Out:
# 3

# %% [markdown]
# ### Usar la función zip()

# %%
nombre_columnas = ['ID','Precio','Cantidad']
variable_1 = ['XC01','XC02','XC03']
variable_2 = [2000,3000,10000]
variable_3 = [3,2,4]

# %%
matriz_completa = list(zip(variable_1, variable_2, variable_3))

# %%
df_zip = pd.DataFrame(data = matriz_completa,
                     columns = nombre_columnas)

# %%
df_zip
# Out:
#      ID  Precio  Cantidad
# 0  XC01    2000         3
# 1  XC02    3000         2
# 2  XC03   10000         4

# %% [markdown]
# ## Mmodificar indexación

# %%
df_1
# Out:
#    variable_1  variable_2
# 0          20           2
# 1          30           4
# 2          40           5
# 3          10           6
# 4          50           7

# %%
df_1.index = ['Propiedad ' + str(i+1) for i in range(df_1.shape[0])]

# %%
df_1
# Out:
#              variable_1  variable_2
# Propiedad 1          20           2
# Propiedad 2          30           4
# Propiedad 3          40           5
# Propiedad 4          10           6
# Propiedad 5          50           7

# %% [markdown]
# ## Manipulación de columnas
# * Mencionando el nombre de la columnas ``df['nombre_columna']``
# * usando el método ``.columns[]``
# * Usando el método ``.loc[]`` $\longrightarrow$ Hacer el llamado por nombre o etiqueta
# * Usando el método ``.iloc[]`` $\longrightarrow$ HAcer el llamado por posición

# %%
import pandas as pd

df =  pd.read_csv('data/diabetes.csv')
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df[['Age']]
# Out:
#      Age
# 0     50
# 1     31
# 2     32
# 3     21
# 4     33
# ..   ...
# 763   63
# 764   27
# 765   30
# 766   47
# 767   23
#
# [768 rows x 1 columns]

# %% [markdown]
# ### Uso de columns

# %%
list(df.columns)
# Out:
# ['Pregnancies',
#  'Glucose',
#  'BloodPressure',
#  'SkinThickness',
#  'Insulin',
#  'BMI',
#  'DiabetesPedigreeFunction',
#  'Age',
#  'Outcome']

# %%
df[df.columns[[5]]]
# Out:
#       BMI
# 0    33.6
# 1    26.6
# 2    23.3
# 3    28.1
# 4    43.1
# ..    ...
# 763  32.9
# 764  36.8
# 765  26.2
# 766  30.1
# 767  30.4
#
# [768 rows x 1 columns]

# %%
df[df.columns[[5,3,0]]]
# Out:
#       BMI  SkinThickness  Pregnancies
# 0    33.6             35            6
# 1    26.6             29            1
# 2    23.3              0            8
# 3    28.1             23            1
# 4    43.1             35            0
# ..    ...            ...          ...
# 763  32.9             48           10
# 764  36.8             27            2
# 765  26.2             23            5
# 766  30.1              0            1
# 767  30.4             31            1
#
# [768 rows x 3 columns]

# %% [markdown]
# ### Usando loc
#
# ``df.loc[rango de las filas, rango de las columnas(mombre)]``

# %%
df.loc[:,['Age']]
# Out:
#      Age
# 0     50
# 1     31
# 2     32
# 3     21
# 4     33
# ..   ...
# 763   63
# 764   27
# 765   30
# 766   47
# 767   23
#
# [768 rows x 1 columns]

# %%
df.loc[:,['Age','BMI']]
# Out:
#      Age   BMI
# 0     50  33.6
# 1     31  26.6
# 2     32  23.3
# 3     21  28.1
# 4     33  43.1
# ..   ...   ...
# 763   63  32.9
# 764   27  36.8
# 765   30  26.2
# 766   47  30.1
# 767   23  30.4
#
# [768 rows x 2 columns]

# %%
df.loc[1:5,['Age','BMI']]
# Out:
#    Age   BMI
# 1   31  26.6
# 2   32  23.3
# 3   21  28.1
# 4   33  43.1
# 5   30  25.6

# %%
df.loc[10:20, :]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 10            4      110             92              0        0  37.6
# 11           10      168             74              0        0  38.0
# 12           10      139             80              0        0  27.1
# 13            1      189             60             23      846  30.1
# 14            5      166             72             19      175  25.8
# 15            7      100              0              0        0  30.0
# 16            0      118             84             47      230  45.8
# 17            7      107             74              0        0  29.6
# 18            1      103             30             38       83  43.3
# 19            1      115             70             30       96  34.6
# 20            3      126             88             41      235  39.3
#
#     DiabetesPedigreeFunction  Age  Outcome
# 10                     0.191   30        0
# 11                     0.537   34        1
# 12                     1.441   57        0
# 13                     0.398   59        1
# 14                     0.587   51        1
# 15                     0.484   32        1
# 16                     0.551   31        1
# 17                     0.254   31        1
# 18                     0.183   33        0
# 19                     0.529   32        1
# 20                     0.704   27        0

# %%
df.loc[[10],:]
# Out:
#     Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 10            4      110             92              0        0  37.6
#
#     DiabetesPedigreeFunction  Age  Outcome
# 10                     0.191   30        0

# %%
df.loc[[10], ['BMI','Age']]
# Out:
#      BMI  Age
# 10  37.6   30

# %% [markdown]
# ### Uso de iloc

# %%
df.iloc[:,[7]]
# Out:
#      Age
# 0     50
# 1     31
# 2     32
# 3     21
# 4     33
# ..   ...
# 763   63
# 764   27
# 765   30
# 766   47
# 767   23
#
# [768 rows x 1 columns]

# %%
df.iloc[:,[7,8]]
# Out:
#      Age  Outcome
# 0     50        1
# 1     31        0
# 2     32        1
# 3     21        0
# 4     33        1
# ..   ...      ...
# 763   63        0
# 764   27        0
# 765   30        0
# 766   47        1
# 767   23        0
#
# [768 rows x 2 columns]

# %%
df.iloc[1:5,[7,8]]
# Out:
#    Age  Outcome
# 1   31        0
# 2   32        1
# 3   21        0
# 4   33        1

# %%
df.iloc[[10],[7,8]]
# Out:
#     Age  Outcome
# 10   30        0

# %%
list(zip(df.index,df.columns))
# Out:
# [(0, 'Pregnancies'),
#  (1, 'Glucose'),
#  (2, 'BloodPressure'),
#  (3, 'SkinThickness'),
#  (4, 'Insulin'),
#  (5, 'BMI'),
#  (6, 'DiabetesPedigreeFunction'),
#  (7, 'Age'),
#  (8, 'Outcome')]

# %% [markdown]
# ## Manipulación de filas

# %% [markdown]
# * Usando el método ``loc[]``
# * Usando el método ``iloc[]``

# %%
url = 'https://raw.githubusercontent.com/carlosrondanp/Python-NaylampUNI/main/data/diabetes.csv'
df = pd.read_csv(url)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 1                       0.351   31        0
# 2                       0.672   32        1
# 3                       0.167   21        0
# 4                       2.288   33        1
# ..                        ...  ...      ...
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.index = [ 'Propiedad '+str(i) for i in range(df.shape[0])]

# %%
df
# Out:
#                Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# Propiedad 0              6      148             72             35        0
# Propiedad 1              1       85             66             29        0
# Propiedad 2              8      183             64              0        0
# Propiedad 3              1       89             66             23       94
# Propiedad 4              0      137             40             35      168
# ...                    ...      ...            ...            ...      ...
# Propiedad 763           10      101             76             48      180
# Propiedad 764            2      122             70             27        0
# Propiedad 765            5      121             72             23      112
# Propiedad 766            1      126             60              0        0
# Propiedad 767            1       93             70             31        0
#
#                 BMI  DiabetesPedigreeFunction  Age  Outcome
# Propiedad 0    33.6                     0.627   50        1
# Propiedad 1    26.6                     0.351   31        0
# Propiedad 2    23.3                     0.672   32        1
# Propiedad 3    28.1                     0.167   21        0
# Propiedad 4    43.1                     2.288   33        1
# ...             ...                       ...  ...      ...
# Propiedad 763  32.9                     0.171   63        0
# Propiedad 764  36.8                     0.340   27        0
# Propiedad 765  26.2                     0.245   30        0
# Propiedad 766  30.1                     0.349   47        1
# Propiedad 767  30.4                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ### Usando Loc

# %%
df.loc[['Propiedad 763'], :]
# Out:
#                Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# Propiedad 763           10      101             76             48      180
#
#                 BMI  DiabetesPedigreeFunction  Age  Outcome
# Propiedad 763  32.9                     0.171   63        0

# %% [markdown]
# ### Usando iloc

# %%
df.iloc[[763],:]
# Out:
#                Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# Propiedad 763           10      101             76             48      180
#
#                 BMI  DiabetesPedigreeFunction  Age  Outcome
# Propiedad 763  32.9                     0.171   63        0

# %% [markdown]
# ## Extraer elemento

# %%
df.loc['Propiedad 763', 'Age']
# Out:
# 63

# %%
df.iloc[763,7]
# Out:
# 63

# %%
df.loc[['Propiedad 763','Propiedad 1'], ['Age']]
# Out:
#                Age
# Propiedad 763   63
# Propiedad 1     31

# %% [markdown]
# ## Métodos en dataframes

# %% [markdown]
# ### Shape: tamaño de un dataframe

# %%
df
# Out:
#                Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# Propiedad 0              6      148             72             35        0
# Propiedad 1              1       85             66             29        0
# Propiedad 2              8      183             64              0        0
# Propiedad 3              1       89             66             23       94
# Propiedad 4              0      137             40             35      168
# ...                    ...      ...            ...            ...      ...
# Propiedad 763           10      101             76             48      180
# Propiedad 764            2      122             70             27        0
# Propiedad 765            5      121             72             23      112
# Propiedad 766            1      126             60              0        0
# Propiedad 767            1       93             70             31        0
#
#                 BMI  DiabetesPedigreeFunction  Age  Outcome
# Propiedad 0    33.6                     0.627   50        1
# Propiedad 1    26.6                     0.351   31        0
# Propiedad 2    23.3                     0.672   32        1
# Propiedad 3    28.1                     0.167   21        0
# Propiedad 4    43.1                     2.288   33        1
# ...             ...                       ...  ...      ...
# Propiedad 763  32.9                     0.171   63        0
# Propiedad 764  36.8                     0.340   27        0
# Propiedad 765  26.2                     0.245   30        0
# Propiedad 766  30.1                     0.349   47        1
# Propiedad 767  30.4                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.shape
# Out:
# (768, 9)

# %% [markdown]
# ### copy: Duplicar un dataframe

# %%
df_copia = df.copy()

# %%
df_copia
# Out:
#                Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# Propiedad 0              6      148             72             35        0
# Propiedad 1              1       85             66             29        0
# Propiedad 2              8      183             64              0        0
# Propiedad 3              1       89             66             23       94
# Propiedad 4              0      137             40             35      168
# ...                    ...      ...            ...            ...      ...
# Propiedad 763           10      101             76             48      180
# Propiedad 764            2      122             70             27        0
# Propiedad 765            5      121             72             23      112
# Propiedad 766            1      126             60              0        0
# Propiedad 767            1       93             70             31        0
#
#                 BMI  DiabetesPedigreeFunction  Age  Outcome
# Propiedad 0    33.6                     0.627   50        1
# Propiedad 1    26.6                     0.351   31        0
# Propiedad 2    23.3                     0.672   32        1
# Propiedad 3    28.1                     0.167   21        0
# Propiedad 4    43.1                     2.288   33        1
# ...             ...                       ...  ...      ...
# Propiedad 763  32.9                     0.171   63        0
# Propiedad 764  36.8                     0.340   27        0
# Propiedad 765  26.2                     0.245   30        0
# Propiedad 766  30.1                     0.349   47        1
# Propiedad 767  30.4                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ### rename (columns = ): renombrar columnas

# %%
df_copia = df_copia.rename(columns = {'Glucose': 'Glucosa',
                           'BMI': 'IMC',
                           'Age': 'Edad',
                           'Outcome': 'Target',
                           'DiabetesPedigreeFunction':'Beta'})

# %% [markdown]
# ### rename(index = ): renombrar indexación

# %%
df_copia.rename(index = {'Propiedad 0': 'Laura Rojas'}, inplace = True)

# %%
df_copia
# Out:
#                Pregnancies  Glucosa  BloodPressure  SkinThickness  Insulin  \
# Laura Rojas              6      148             72             35        0
# Propiedad 1              1       85             66             29        0
# Propiedad 2              8      183             64              0        0
# Propiedad 3              1       89             66             23       94
# Propiedad 4              0      137             40             35      168
# ...                    ...      ...            ...            ...      ...
# Propiedad 763           10      101             76             48      180
# Propiedad 764            2      122             70             27        0
# Propiedad 765            5      121             72             23      112
# Propiedad 766            1      126             60              0        0
# Propiedad 767            1       93             70             31        0
#
#                 IMC   Beta  Edad  Target
# Laura Rojas    33.6  0.627    50       1
# Propiedad 1    26.6  0.351    31       0
# Propiedad 2    23.3  0.672    32       1
# Propiedad 3    28.1  0.167    21       0
# Propiedad 4    43.1  2.288    33       1
# ...             ...    ...   ...     ...
# Propiedad 763  32.9  0.171    63       0
# Propiedad 764  36.8  0.340    27       0
# Propiedad 765  26.2  0.245    30       0
# Propiedad 766  30.1  0.349    47       1
# Propiedad 767  30.4  0.315    23       0
#
# [768 rows x 9 columns]

# %% [markdown]
# ## drop(labels = [ ] , axis = 0): Eliminar filas

# %%
df_copia.drop(labels = ['Laura Rojas','Propiedad 764'], axis = 0, inplace = True)

# %%
df_copia
# Out:
#                Pregnancies  Glucosa  BloodPressure  SkinThickness  Insulin  \
# Propiedad 1              1       85             66             29        0
# Propiedad 2              8      183             64              0        0
# Propiedad 3              1       89             66             23       94
# Propiedad 4              0      137             40             35      168
# Propiedad 5              5      116             74              0        0
# ...                    ...      ...            ...            ...      ...
# Propiedad 762            9       89             62              0        0
# Propiedad 763           10      101             76             48      180
# Propiedad 765            5      121             72             23      112
# Propiedad 766            1      126             60              0        0
# Propiedad 767            1       93             70             31        0
#
#                 IMC   Beta  Edad  Target
# Propiedad 1    26.6  0.351    31       0
# Propiedad 2    23.3  0.672    32       1
# Propiedad 3    28.1  0.167    21       0
# Propiedad 4    43.1  2.288    33       1
# Propiedad 5    25.6  0.201    30       0
# ...             ...    ...   ...     ...
# Propiedad 762  22.5  0.142    33       0
# Propiedad 763  32.9  0.171    63       0
# Propiedad 765  26.2  0.245    30       0
# Propiedad 766  30.1  0.349    47       1
# Propiedad 767  30.4  0.315    23       0
#
# [766 rows x 9 columns]

# %% [markdown]
# ## drop(labels = [ ], axis = 1): eliminar columnas

# %%
df_copia.drop(labels = ['Glucosa', 'Beta'], axis = 1, inplace = True)

# %%
df_copia
# Out:
#                Pregnancies  BloodPressure  SkinThickness  Insulin   IMC  Edad  \
# Propiedad 1              1             66             29        0  26.6    31
# Propiedad 2              8             64              0        0  23.3    32
# Propiedad 3              1             66             23       94  28.1    21
# Propiedad 4              0             40             35      168  43.1    33
# Propiedad 5              5             74              0        0  25.6    30
# ...                    ...            ...            ...      ...   ...   ...
# Propiedad 762            9             62              0        0  22.5    33
# Propiedad 763           10             76             48      180  32.9    63
# Propiedad 765            5             72             23      112  26.2    30
# Propiedad 766            1             60              0        0  30.1    47
# Propiedad 767            1             70             31        0  30.4    23
#
#                Target
# Propiedad 1         0
# Propiedad 2         1
# Propiedad 3         0
# Propiedad 4         1
# Propiedad 5         0
# ...               ...
# Propiedad 762       0
# Propiedad 763       0
# Propiedad 765       0
# Propiedad 766       1
# Propiedad 767       0
#
# [766 rows x 7 columns]

# %% [markdown]
# ## unique(), value_counts()

# %%
df
# Out:
#                Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# Propiedad 0              6      148             72             35        0
# Propiedad 1              1       85             66             29        0
# Propiedad 2              8      183             64              0        0
# Propiedad 3              1       89             66             23       94
# Propiedad 4              0      137             40             35      168
# ...                    ...      ...            ...            ...      ...
# Propiedad 763           10      101             76             48      180
# Propiedad 764            2      122             70             27        0
# Propiedad 765            5      121             72             23      112
# Propiedad 766            1      126             60              0        0
# Propiedad 767            1       93             70             31        0
#
#                 BMI  DiabetesPedigreeFunction  Age  Outcome
# Propiedad 0    33.6                     0.627   50        1
# Propiedad 1    26.6                     0.351   31        0
# Propiedad 2    23.3                     0.672   32        1
# Propiedad 3    28.1                     0.167   21        0
# Propiedad 4    43.1                     2.288   33        1
# ...             ...                       ...  ...      ...
# Propiedad 763  32.9                     0.171   63        0
# Propiedad 764  36.8                     0.340   27        0
# Propiedad 765  26.2                     0.245   30        0
# Propiedad 766  30.1                     0.349   47        1
# Propiedad 767  30.4                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
print(df['Pregnancies'].unique())
# Out:
# [ 6  1  8  0  5  3 10  2  4  7  9 11 13 15 17 12 14]

# %%
df[['Pregnancies']].value_counts()
# Out:
# Pregnancies
# 1              135
# 0              111
# 2              103
# 3               75
# 4               68
# 5               57
# 6               50
# 7               45
# 8               38
# 9               28
# 10              24
# 11              11
# 13              10
# 12               9
# 14               2
# 15               1
# 17               1
# dtype: int64

# %% [markdown]
# ### apply

# %%
df
# Out:
#                Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# Propiedad 0              6      148             72             35        0
# Propiedad 1              1       85             66             29        0
# Propiedad 2              8      183             64              0        0
# Propiedad 3              1       89             66             23       94
# Propiedad 4              0      137             40             35      168
# ...                    ...      ...            ...            ...      ...
# Propiedad 763           10      101             76             48      180
# Propiedad 764            2      122             70             27        0
# Propiedad 765            5      121             72             23      112
# Propiedad 766            1      126             60              0        0
# Propiedad 767            1       93             70             31        0
#
#                 BMI  DiabetesPedigreeFunction  Age  Outcome
# Propiedad 0    33.6                     0.627   50        1
# Propiedad 1    26.6                     0.351   31        0
# Propiedad 2    23.3                     0.672   32        1
# Propiedad 3    28.1                     0.167   21        0
# Propiedad 4    43.1                     2.288   33        1
# ...             ...                       ...  ...      ...
# Propiedad 763  32.9                     0.171   63        0
# Propiedad 764  36.8                     0.340   27        0
# Propiedad 765  26.2                     0.245   30        0
# Propiedad 766  30.1                     0.349   47        1
# Propiedad 767  30.4                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df['Glucose'] = df['Glucose'].apply(lambda i: i**(1/2))

# %%
df
# Out:
#                Pregnancies    Glucose  BloodPressure  SkinThickness  Insulin  \
# Propiedad 0              6  12.165525             72             35        0
# Propiedad 1              1   9.219544             66             29        0
# Propiedad 2              8  13.527749             64              0        0
# Propiedad 3              1   9.433981             66             23       94
# Propiedad 4              0  11.704700             40             35      168
# ...                    ...        ...            ...            ...      ...
# Propiedad 763           10  10.049876             76             48      180
# Propiedad 764            2  11.045361             70             27        0
# Propiedad 765            5  11.000000             72             23      112
# Propiedad 766            1  11.224972             60              0        0
# Propiedad 767            1   9.643651             70             31        0
#
#                 BMI  DiabetesPedigreeFunction  Age  Outcome
# Propiedad 0    33.6                     0.627   50        1
# Propiedad 1    26.6                     0.351   31        0
# Propiedad 2    23.3                     0.672   32        1
# Propiedad 3    28.1                     0.167   21        0
# Propiedad 4    43.1                     2.288   33        1
# ...             ...                       ...  ...      ...
# Propiedad 763  32.9                     0.171   63        0
# Propiedad 764  36.8                     0.340   27        0
# Propiedad 765  26.2                     0.245   30        0
# Propiedad 766  30.1                     0.349   47        1
# Propiedad 767  30.4                     0.315   23        0
#
# [768 rows x 9 columns]

# %% [markdown]
# ### Groupby

# %%
df.groupby(['Outcome']).mean()
# Out:
#          Pregnancies    Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  10.391761      68.184000      19.664000   68.792000
# 1           4.865672  11.775727      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
df.groupby(['Outcome','Pregnancies']).mean()
# Out:
#                        Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome Pregnancies
# 0       0            10.523854      69.205479      21.054795   77.561644
#         1            10.009970      66.830189      23.047170   84.320755
#         2            10.207918      61.940476      20.107143   72.619048
#         3            10.400846      65.708333      17.520833   62.020833
#         4            10.777873      71.577778      18.422222   78.466667
#         5            10.498124      74.666667      17.166667   46.861111
#         6            10.674163      66.382353      18.705882   69.029412
#         7            10.923481      70.350000      19.350000   72.500000
#         8            10.243505      75.312500      12.937500   14.500000
#         9            10.247015      70.400000      22.400000   71.200000
#         10           10.754922      72.857143      10.571429   25.071429
#         11           10.596301      81.000000      10.000000    0.000000
#         12           10.501724      80.200000      24.600000   31.800000
#         13           10.743994      74.400000      22.000000   50.000000
# 1       0            11.953257      63.210526      24.605263   89.578947
#         1            11.920845      71.310345      29.517241  151.137931
#         2            11.560792      69.052632      28.210526  144.315789
#         3            12.111537      68.148148      24.629630  132.666667
#         4            11.787510      67.000000      10.913043   51.782609
#         5            11.116824      78.857143      17.761905   75.190476
#         6            11.079526      72.750000      15.375000   52.000000
#         7            12.116704      71.120000      21.040000   94.040000
#         8            12.176268      75.090909      20.500000  149.772727
#         9            11.999056      82.055556      20.055556   57.555556
#         10           11.154221      66.500000      22.900000   48.400000
#         11           11.560923      70.285714      28.428571  102.857143
#         12           10.719295      71.500000      30.250000  213.500000
#         13           11.535892      73.200000      12.600000    5.800000
#         14           11.614378      70.000000      27.500000   92.000000
#         15           11.661904      70.000000      32.000000  110.000000
#         17           12.767145      72.000000      41.000000  114.000000
#
#                            BMI  DiabetesPedigreeFunction        Age
# Outcome Pregnancies
# 0       0            31.727397                  0.457055  27.095890
#         1            29.616038                  0.451679  25.254717
#         2            29.679762                  0.479881  25.892857
#         3            29.231250                  0.358354  28.770833
#         4            31.255556                  0.410511  30.066667
#         5            31.100000                  0.359278  39.416667
#         6            29.591176                  0.433294  37.147059
#         7            29.975000                  0.405500  42.500000
#         8            30.693750                  0.526750  49.625000
#         9            28.840000                  0.311100  46.000000
#         10           30.114286                  0.411071  43.357143
#         11           37.125000                  0.259000  40.750000
#         12           30.560000                  0.301200  48.200000
#         13           33.280000                  0.405600  46.800000
# 1       0            39.213158                  0.643368  28.578947
#         1            37.793103                  0.613759  35.103448
#         2            34.578947                  0.543737  32.947368
#         3            32.548148                  0.563333  29.481481
#         4            33.873913                  0.516478  38.086957
#         5            36.780952                  0.460095  38.380952
#         6            31.775000                  0.421500  44.000000
#         7            34.756000                  0.474120  40.000000
#         8            32.204545                  0.488682  42.272727
#         9            33.300000                  0.683778  43.166667
#         10           31.380000                  0.514500  41.700000
#         11           39.385714                  0.673143  46.714286
#         12           34.575000                  0.623250  46.500000
#         13           36.720000                  0.521000  42.200000
#         14           35.100000                  0.312000  42.000000
#         15           37.100000                  0.153000  43.000000
#         17           40.900000                  0.817000  47.000000

# %% [markdown]
# Podemos usar métodos como: ``mean()``, ``meadian()``, ``sum()``, ``min()``, ``max()``, ``count()``
#
# Usaremos el método ``.agg()``

# %%
df.groupby(['Outcome']).agg(np.mean)
# Out:
#          Pregnancies    Glucose  BloodPressure  SkinThickness     Insulin  \
# Outcome
# 0           3.298000  10.391761      68.184000      19.664000   68.792000
# 1           4.865672  11.775727      70.824627      22.164179  100.335821
#
#                BMI  DiabetesPedigreeFunction        Age
# Outcome
# 0        30.304200                  0.429734  31.190000
# 1        35.142537                  0.550500  37.067164

# %%
df.groupby(['Outcome','Pregnancies']).agg([np.min, np.max, np.mean, np.std])[['Glucose','Age']]
# Out:
#                        Glucose                                  Age       \
#                           amin       amax       mean       std amin amax
# Outcome Pregnancies
# 0       0             7.549834  13.152946  10.523854  1.100127   21   67
#         1             0.000000  13.892444  10.009970  2.023324   21   62
#         2             7.483315  13.228757  10.207918  1.012367   21   72
#         3             7.810250  13.820275  10.400846  1.207028   21   63
#         4             8.717798  14.035669  10.777873  1.193596   21   63
#         5             6.633250  12.569805  10.498124  1.223792   24   69
#         6             8.944272  13.527749  10.674163  1.207507   23   66
#         7             7.874008  13.379088  10.923481  1.328859   24   61
#         8             8.062258  13.928388  10.243505  1.344860   34   68
#         9             7.549834  12.409674  10.247015  1.490224   33   81
#         10            8.246211  13.379088  10.754922  1.431596   29   63
#         11            9.219544  11.747340  10.596301  1.136313   35   51
#         12            9.380832  11.832160  10.501724  0.944582   41   62
#         13            8.717798  12.369317  10.743994  1.486016   39   57
# 1       0             9.746794  14.071247  11.953257  1.180314   21   62
#         1             9.380832  14.106736  11.920845  1.321665   21   59
#         2             9.486833  14.035669  11.560792  1.386721   21   66
#         3             8.831761  13.892444  12.111537  1.350042   22   52
#         4             9.746794  13.564660  11.787510  1.005798   22   70
#         5             0.000000  13.747727  11.116824  2.826136   25   58
#         6             0.000000  13.964240  11.079526  3.203181   29   66
#         7             9.848858  14.000000  12.116704  1.438127   29   55
#         8            10.000000  14.035669  12.176268  1.349546   22   60
#         9            10.099505  13.564660  11.999056  1.011927   29   54
#         10            9.486833  12.961481  11.154221  1.146660   30   56
#         11           10.535654  12.449900  11.560923  0.634489   40   51
#         12            9.165151  12.288206  10.719295  1.569168   38   58
#         13           10.198039  12.569805  11.535892  0.950783   38   44
#         14           10.000000  13.228757  11.614378  2.283076   38   46
#         15           11.661904  11.661904  11.661904       NaN   43   43
#         17           12.767145  12.767145  12.767145       NaN   47   47
#
#
#                           mean        std
# Outcome Pregnancies
# 0       0            27.095890  10.276949
#         1            25.254717   6.253473
#         2            25.892857   7.783235
#         3            28.770833   8.817873
#         4            30.066667   7.164940
#         5            39.416667  13.795185
#         6            37.147059  11.962397
#         7            42.500000   9.023361
#         8            49.625000  10.990147
#         9            46.000000  14.251706
#         10           43.357143  10.580149
#         11           40.750000   7.588368
#         12           48.200000   8.136338
#         13           46.800000   7.563068
# 1       0            28.578947   8.487293
#         1            35.103448   9.461746
#         2            32.947368  13.966124
#         3            29.481481   6.784430
#         4            38.086957  14.813731
#         5            38.380952  10.037311
#         6            44.000000  10.905656
#         7            40.000000   6.928203
#         8            42.272727   9.557753
#         9            43.166667   7.815896
#         10           41.700000   7.789594
#         11           46.714286   4.461475
#         12           46.500000   8.386497
#         13           42.200000   2.489980
#         14           42.000000   5.656854
#         15           43.000000        NaN
#         17           47.000000        NaN

# %%
df
# Out:
#                Pregnancies    Glucose  BloodPressure  SkinThickness  Insulin  \
# Propiedad 0              6  12.165525             72             35        0
# Propiedad 1              1   9.219544             66             29        0
# Propiedad 2              8  13.527749             64              0        0
# Propiedad 3              1   9.433981             66             23       94
# Propiedad 4              0  11.704700             40             35      168
# ...                    ...        ...            ...            ...      ...
# Propiedad 763           10  10.049876             76             48      180
# Propiedad 764            2  11.045361             70             27        0
# Propiedad 765            5  11.000000             72             23      112
# Propiedad 766            1  11.224972             60              0        0
# Propiedad 767            1   9.643651             70             31        0
#
#                 BMI  DiabetesPedigreeFunction  Age  Outcome
# Propiedad 0    33.6                     0.627   50        1
# Propiedad 1    26.6                     0.351   31        0
# Propiedad 2    23.3                     0.672   32        1
# Propiedad 3    28.1                     0.167   21        0
# Propiedad 4    43.1                     2.288   33        1
# ...             ...                       ...  ...      ...
# Propiedad 763  32.9                     0.171   63        0
# Propiedad 764  36.8                     0.340   27        0
# Propiedad 765  26.2                     0.245   30        0
# Propiedad 766  30.1                     0.349   47        1
# Propiedad 767  30.4                     0.315   23        0
#
# [768 rows x 9 columns]

# %%
df.groupby(['Outcome']).transform(lambda x: (x-x.mean())/x.std())
# Out:
#                Pregnancies   Glucose  BloodPressure  SkinThickness   Insulin  \
# Propiedad 0       0.303196  0.241770       0.054689       0.726020 -0.723458
# Propiedad 1      -0.761637 -0.829862      -0.120910       0.627000 -0.695815
# Propiedad 2       0.837778  1.086681      -0.317545      -1.253651 -0.723458
# Propiedad 3      -0.761637 -0.678053      -0.120910       0.224044  0.254973
# Propiedad 4      -1.300551 -0.044054      -1.434250       0.726020  0.487884
# ...                    ...       ...            ...            ...       ...
# Propiedad 763     2.221276 -0.242035       0.432706       1.903029  1.124844
# Propiedad 764    -0.430202  0.462711       0.100537       0.492681 -0.695815
# Propiedad 765     0.564102  0.430598       0.211260       0.224044  0.437039
# Propiedad 766    -1.033260 -0.341603      -0.503663      -1.253651 -0.723458
# Propiedad 767    -0.761637 -0.529619       0.100537       0.761319 -0.695815
#
#                     BMI  DiabetesPedigreeFunction       Age
# Propiedad 0   -0.212384                  0.205449  1.179115
# Propiedad 1   -0.481700                 -0.263249 -0.016284
# Propiedad 2   -1.630537                  0.326302 -0.461985
# Propiedad 3   -0.286637                 -0.878458 -0.873355
# Propiedad 4    1.095621                  4.666252 -0.370812
# ...                 ...                       ...       ...
# Propiedad 763  0.337562                 -0.865084  2.726341
# Propiedad 764  0.844723                 -0.300028 -0.359112
# Propiedad 765 -0.533716                 -0.617663 -0.101991
# Propiedad 766 -0.694281                 -0.541151  0.905599
# Propiedad 767  0.012458                 -0.383616 -0.701941
#
# [768 rows x 8 columns]
