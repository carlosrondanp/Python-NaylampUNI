# %% [markdown]
# # Proceso de modelamiento

# %% [markdown]
# * **Dataset:** Total de datos sobre el que queremos desarrollar un algoritmo de *Machine learning*. Dicha contendrá variables independientes y variables dependientes
# * **Feactures (variables independientes):** columnas del dataset que serán usaras por el algoritmo para generar un modelo.
# * **Target (Variables depentientes):** Columna del dataset que se desea predecir conel futuro modelo
# * **Train (conjunto de datos de entrenamiento):** Subconjuto del dataset que será usado para entrenar el modelo.
# * **Test (conjunto de datos de test):** Subconjuto del dataset que se le pasará el modelo para genrar los indicadores más importantes de calidad
# * **Val (conjunto de validación):** Subconjutno del dataset que se usa para medir el rendimiento del modelo en el mismo instante de su entrenamiento

# %% [markdown]
# ![aprendizaje_supervisado-2.png](attachment:aprendizaje_supervisado-2.png)

# %% [markdown]
# ## Preprocesamiento
# Esta etapa le preceden:
# * *Conocimiento del negocio:* Principalmente es saber tener en claro el Objetivo del proyecto.
# * *Conocimiento de la data:* Saber de dónde extraerá la data, cuál es su volumen, determinar la calidad de la data

# %% [markdown]
# ### Importar librerías y cargar dataset

# %%
import pandas as pd #Usado para la manipulación de dataframes
import numpy as np #Realizar operaciones matemáticas
import matplotlib.pyplot as plt #Realizar gráficas

# %%
df = pd.read_csv('data/loan_prediction.csv')
df
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# ..        ...     ...     ...        ...           ...           ...
# 609  LP002978  Female      No          0      Graduate            No
# 610  LP002979    Male     Yes         3+      Graduate            No
# 611  LP002983    Male     Yes          1      Graduate            No
# 612  LP002984    Male     Yes          2      Graduate            No
# 613  LP002990  Female      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# ...

# %% [markdown]
# - **Loan_ID**
# - **Gender:** Género
# - **Married:** Estado civil
# - **Dependents:** Cantidad de personas que dependan de esta
# - **Education:** Nivel de educación
# - **Self_employed:** Trabaja por cuenta propia
# - **Applicant Income:** Ingresos
# - **Loan Amount:** Mónto de préstamo
# - **Loan_Amount_Term:** Monto del préstamo plazo
# - **Credit_History:** Historial de crédito
# - **Property_Area:** Tipo de área de la propiedad
# - **Loan_Status:** Estado del préstamo

# %%
print('Filas: {}\ncolumnas: {}'.format(df.shape[0],df.shape[1]))
# Out:
# Filas: 614
# columnas: 13

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe(include= 'all')
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
# mean         NaN    NaN     NaN        NaN       NaN           NaN
# std          NaN    NaN     NaN        NaN       NaN           NaN
# min          NaN    NaN     NaN        NaN       NaN           NaN
# 25%          NaN    NaN     NaN        NaN       NaN           NaN
# 50%          NaN    NaN     NaN        NaN       NaN           NaN
# 75%          NaN    NaN     NaN        NaN       NaN           NaN
# max          NaN    NaN     NaN        NaN       NaN           NaN
#
#         ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count        614.000000         614.000000  592.000000         600.00000
# ...

# %% [markdown]
# Generaremos una lista de vairables únicamente strings ``Objects``

# %%
texto = [x for x in df.select_dtypes(include = ['object']).columns]
texto
# Out:
# ['Loan_ID',
#  'Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Property_Area',
#  'Loan_Status']

# %% [markdown]
# Generaremos una lista de vairables únicamente decimales ``float``

# %%
numerico =[x for x in df.select_dtypes(include = [np.number]).columns]
numerico
# Out:
# ['ApplicantIncome',
#  'CoapplicantIncome',
#  'LoanAmount',
#  'Loan_Amount_Term',
#  'Credit_History']

# %%
df[texto].describe()
# Out:
#          Loan_ID Gender Married Dependents Education Self_Employed  \
# count        614    601     611        599       614           582
# unique       614      2       2          4         2             2
# top     LP001002   Male     Yes          0  Graduate            No
# freq           1    489     398        345       480           500
#
#        Property_Area Loan_Status
# count            614         614
# unique             3           2
# top        Semiurban           Y
# freq             233         422

# %%
df[numerico].describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
#Enlistaremos nuestras variables para poder manipularalas más facilmente
list(zip([i for i in range(df.shape[0])],df.columns))
# Out:
# [(0, 'Loan_ID'),
#  (1, 'Gender'),
#  (2, 'Married'),
#  (3, 'Dependents'),
#  (4, 'Education'),
#  (5, 'Self_Employed'),
#  (6, 'ApplicantIncome'),
#  (7, 'CoapplicantIncome'),
#  (8, 'LoanAmount'),
#  (9, 'Loan_Amount_Term'),
#  (10, 'Credit_History'),
#  (11, 'Property_Area'),
#  (12, 'Loan_Status')]

# %%
df.rename(columns = {'Gender':'Genero',
                    'Married': 'Casado',
                    'Dependents': 'Dependientes', 
                    'Eduaction': 'Educacion',
                    'Self_Employed': 'Autoempleado',
                    'ApplicantIncome': 'Ingresos',
                    'CoapplicantIncome': 'Ingresos_cosolicitante',
                    'LoanAmount':'Monto',
                    'Loan_Amount_Term': 'Monto_plazo',
                    'Credit_History': 'credito',
                    'Property_Area': 'Propiedad',
                    'Loan_Status': 'Target'}, inplace = True)
df
# Out:
#       Loan_ID  Genero Casado Dependientes     Education Autoempleado  \
# 0    LP001002    Male     No            0      Graduate           No
# 1    LP001003    Male    Yes            1      Graduate           No
# 2    LP001005    Male    Yes            0      Graduate          Yes
# 3    LP001006    Male    Yes            0  Not Graduate           No
# 4    LP001008    Male     No            0      Graduate           No
# ..        ...     ...    ...          ...           ...          ...
# 609  LP002978  Female     No            0      Graduate           No
# 610  LP002979    Male    Yes           3+      Graduate           No
# 611  LP002983    Male    Yes            1      Graduate           No
# 612  LP002984    Male    Yes            2      Graduate           No
# 613  LP002990  Female     No            0      Graduate          Yes
#
#      Ingresos  Ingresos_cosolicitante  Monto  Monto_plazo  credito  Propiedad  \
# ...

# %%
df.head()
# Out:
#     Loan_ID Genero Casado Dependientes     Education Autoempleado  Ingresos  \
# 0  LP001002   Male     No            0      Graduate           No      5849
# 1  LP001003   Male    Yes            1      Graduate           No      4583
# 2  LP001005   Male    Yes            0      Graduate          Yes      3000
# 3  LP001006   Male    Yes            0  Not Graduate           No      2583
# 4  LP001008   Male     No            0      Graduate           No      6000
#
#    Ingresos_cosolicitante  Monto  Monto_plazo  credito Propiedad Target
# 0                     0.0    NaN        360.0      1.0     Urban      Y
# 1                  1508.0  128.0        360.0      1.0     Rural      N
# 2                     0.0   66.0        360.0      1.0     Urban      Y
# 3                  2358.0  120.0        360.0      1.0     Urban      Y
# 4                     0.0  141.0        360.0      1.0     Urban      Y

# %%
df['Target'].value_counts()
# Out:
# Y    422
# N    192
# Name: Target, dtype: int64

# %% [markdown]
# Observamos que la variable ``target`` es binaria.

# %%
(df['Target'].unique())
# Out:
# array(['Y', 'N'], dtype=object)

# %% [markdown]
# El tipo de datos de la variable ``target`` es ``Object`` es decir, texto. Para poder manipularlo dentro de un modelo debemos convertiro a numérico

# %%
df['Target'] = df['Target'].map({'Y':0,
                                 'N':1})

# %%
df.head()
# Out:
#     Loan_ID Genero Casado Dependientes     Education Autoempleado  Ingresos  \
# 0  LP001002   Male     No            0      Graduate           No      5849
# 1  LP001003   Male    Yes            1      Graduate           No      4583
# 2  LP001005   Male    Yes            0      Graduate          Yes      3000
# 3  LP001006   Male    Yes            0  Not Graduate           No      2583
# 4  LP001008   Male     No            0      Graduate           No      6000
#
#    Ingresos_cosolicitante  Monto  Monto_plazo  credito Propiedad  Target
# 0                     0.0    NaN        360.0      1.0     Urban       0
# 1                  1508.0  128.0        360.0      1.0     Rural       1
# 2                     0.0   66.0        360.0      1.0     Urban       0
# 3                  2358.0  120.0        360.0      1.0     Urban       0
# 4                     0.0  141.0        360.0      1.0     Urban       0

# %%
df.drop(labels = ['Loan_ID'], axis = 1,inplace=True)

# %% [markdown]
# ### División de train y test

# %%
df.head()
# Out:
#   Genero Casado Dependientes     Education Autoempleado  Ingresos  \
# 0   Male     No            0      Graduate           No      5849
# 1   Male    Yes            1      Graduate           No      4583
# 2   Male    Yes            0      Graduate          Yes      3000
# 3   Male    Yes            0  Not Graduate           No      2583
# 4   Male     No            0      Graduate           No      6000
#
#    Ingresos_cosolicitante  Monto  Monto_plazo  credito Propiedad  Target
# 0                     0.0    NaN        360.0      1.0     Urban       0
# 1                  1508.0  128.0        360.0      1.0     Rural       1
# 2                     0.0   66.0        360.0      1.0     Urban       0
# 3                  2358.0  120.0        360.0      1.0     Urban       0
# 4                     0.0  141.0        360.0      1.0     Urban       0

# %%
X = df.drop('Target', axis = 1)
y = df[['Target']]

# %%
X
# Out:
#      Genero Casado Dependientes     Education Autoempleado  Ingresos  \
# 0      Male     No            0      Graduate           No      5849
# 1      Male    Yes            1      Graduate           No      4583
# 2      Male    Yes            0      Graduate          Yes      3000
# 3      Male    Yes            0  Not Graduate           No      2583
# 4      Male     No            0      Graduate           No      6000
# ..      ...    ...          ...           ...          ...       ...
# 609  Female     No            0      Graduate           No      2900
# 610    Male    Yes           3+      Graduate           No      4106
# 611    Male    Yes            1      Graduate           No      8072
# 612    Male    Yes            2      Graduate           No      7583
# 613  Female     No            0      Graduate          Yes      4583
#
#      Ingresos_cosolicitante  Monto  Monto_plazo  credito  Propiedad
# 0                       0.0    NaN        360.0      1.0      Urban
# ...

# %%
X.shape
# Out:
# (614, 11)

# %%
y.shape
# Out:
# (614, 1)

# %%
from sklearn.model_selection import train_test_split

# %%
semilla = 23

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state = semilla)

# %%
X_train
# Out:
#      Genero Casado Dependientes     Education Autoempleado  Ingresos  \
# 190    Male     No            0  Not Graduate           No      4885
# 388    Male    Yes            0      Graduate           No      2333
# 350    Male    Yes            0      Graduate           No      9083
# 421  Female     No            0  Not Graduate           No      2720
# 172    Male    Yes           3+  Not Graduate           No      3522
# ..      ...    ...          ...           ...          ...       ...
# 237  Female     No            0      Graduate          Yes      3463
# 31     Male     No            0      Graduate           No      3167
# 488    Male    Yes            2      Graduate          Yes      4583
# 40     Male     No            0      Graduate           No      3600
# 595    Male     No            0  Not Graduate           No      3833
#
#      Ingresos_cosolicitante  Monto  Monto_plazo  credito  Propiedad
# 190                     0.0   48.0        360.0      1.0      Rural
# ...

# %%
y_train.value_counts()
# Out:
# Target
# 0         346
# 1         145
# dtype: int64

# %%
y_test.value_counts()
# Out:
# Target
# 0         76
# 1         47
# dtype: int64

# %% [markdown]
# ### Análisis exploratorio de datos

# %%
X_train.head()
# Out:
#      Genero Casado Dependientes     Education Autoempleado  Ingresos  \
# 190    Male     No            0  Not Graduate           No      4885
# 388    Male    Yes            0      Graduate           No      2333
# 350    Male    Yes            0      Graduate           No      9083
# 421  Female     No            0  Not Graduate           No      2720
# 172    Male    Yes           3+  Not Graduate           No      3522
#
#      Ingresos_cosolicitante  Monto  Monto_plazo  credito  Propiedad
# 190                     0.0   48.0        360.0      1.0      Rural
# 388                  2417.0  136.0        360.0      1.0      Urban
# 350                     0.0  228.0        360.0      1.0  Semiurban
# 421                     0.0   80.0          NaN      0.0      Urban
# 172                     0.0   81.0        180.0      1.0      Rural

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 190 to 595
# Data columns (total 11 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Genero                  480 non-null    object
#  1   Casado                  490 non-null    object
#  2   Dependientes            481 non-null    object
#  3   Education               491 non-null    object
#  4   Autoempleado            466 non-null    object
#  5   Ingresos                491 non-null    int64
#  6   Ingresos_cosolicitante  491 non-null    float64
#  7   Monto                   476 non-null    float64
#  8   Monto_plazo             486 non-null    float64
#  9   credito                 452 non-null    float64
#  10  Propiedad               491 non-null    object
# dtypes: float64(4), int64(1), object(6)
# memory usage: 46.0+ KB

# %%
X_train.describe()
# Out:
#            Ingresos  Ingresos_cosolicitante       Monto  Monto_plazo  \
# count    491.000000              491.000000  476.000000   486.000000
# mean    5322.364562             1579.319593  145.228992   341.604938
# std     6205.528418             2605.904012   84.810079    65.211917
# min      150.000000                0.000000    9.000000    12.000000
# 25%     2809.000000                0.000000  100.000000   360.000000
# 50%     3750.000000             1040.000000  127.000000   360.000000
# 75%     5736.000000             2316.000000  165.000000   360.000000
# max    81000.000000            33837.000000  700.000000   480.000000
#
#           credito
# count  452.000000
# mean     0.860619
# std      0.346727
# min      0.000000
# 25%      1.000000
# 50%      1.000000
# 75%      1.000000
# max      1.000000

# %%
X_train.describe(include = 'object')
# Out:
#        Genero Casado Dependientes Education Autoempleado  Propiedad
# count     480    490          481       491          466        491
# unique      2      2            4         2            2          3
# top      Male    Yes            0  Graduate           No  Semiurban
# freq      393    316          281       385          396        183

# %% [markdown]
# #### Visualización de datos

# %%
X_train.hist(bins=25 ,figsize = (10,10))
# Out:
# array([[<AxesSubplot:title={'center':'Ingresos'}>,
#         <AxesSubplot:title={'center':'Ingresos_cosolicitante'}>],
#        [<AxesSubplot:title={'center':'Monto'}>,
#         <AxesSubplot:title={'center':'Monto_plazo'}>],
#        [<AxesSubplot:title={'center':'credito'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
X_train.plot(kind = 'density', subplots = True, layout = (3,2), figsize = (15,8)); #density,hist (bins = 40)

# %%
import seaborn as sns

# %%
#plt.figure(figsize= (15,5))
sns.histplot(data = X_train,
            x = 'Ingresos')
# Out:
# <AxesSubplot:xlabel='Ingresos', ylabel='Count'>

# %%
plt.figure(figsize= (15,5))
sns.distplot(X_train['Ingresos'])
# Out:
# C:\Users\CARLOS\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning:
#
# `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
# <AxesSubplot:xlabel='Ingresos', ylabel='Density'>

# %%
sns.boxplot(data = df, #usamos df porque en la data X_train no se encuentra 'Train' 
           x = 'Target',
           y = 'Ingresos')
# Out:
# <AxesSubplot:xlabel='Target', ylabel='Ingresos'>

# %%
plt.figure(figsize= (20,5))
sns.boxplot(data = df,
            x = 'Ingresos')
# Out:
# <AxesSubplot:xlabel='Ingresos'>

# %%
from plotly.offline import iplot

import plotly
import plotly.graph_objs as go

# %%
caja = go.Box(y=df['Ingresos'],name='Ingresos')
iplot([caja])
# Out:
# <div>                            <div id="58d6dcd8-3a1a-4dc8-89d3-d1ab533c679a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58d6dcd8-3a1a-4dc8-89d3-d1ab533c679a")) {                    Plotly.newPlot(                        "58d6dcd8-3a1a-4dc8-89d3-d1ab533c679a",                        [{"name":"Ingresos","y":[5849,4583,3000,2583,6000,5417,2333,3036,4006,12841,3200,2500,3073,1853,1299,4950,3596,3510,4887,2600,7660,5955,2600,3365,3717,9560,2799,4226,1442,3750,4166,3167,4692,3500,12500,2275,1828,3667,4166,3748,3600,1800,2400,3941,4695,3410,5649,5821,2645,4000,1928,3086,4230,4616,11500,2708,2132,3366,8080,3357,2500,3029,2609,4945,4166,5726,3200,10750,7100,4300,3208,1875,3500,4755,5266,3750,3750,1000,3167,3333,3846,2395,1378,6000,3988,2366,3333,2500
# ...

# %%
sns.countplot(data = X_train, x = 'Dependientes')
# Out:
# <AxesSubplot:xlabel='Dependientes', ylabel='count'>

# %%
X_train[X_train['Dependientes'] == '3+'].head()
# Out:
#     Genero Casado Dependientes     Education Autoempleado  Ingresos  \
# 172   Male    Yes           3+  Not Graduate           No      3522
# 211   Male    Yes           3+      Graduate           No      3430
# 409   Male    Yes           3+      Graduate           No     81000
# 343   Male    Yes           3+  Not Graduate           No      3173
# 34    Male     No           3+      Graduate           No     12500
#
#      Ingresos_cosolicitante  Monto  Monto_plazo  credito  Propiedad
# 172                     0.0   81.0        180.0      1.0      Rural
# 211                  1250.0  128.0        360.0      0.0  Semiurban
# 409                     0.0  360.0        360.0      0.0      Rural
# 343                     0.0   74.0        360.0      1.0  Semiurban
# 34                   3000.0  320.0        360.0      1.0      Rural

# %% [markdown]
# #### Transformación de variables

# %%
X_train
# Out:
#      Genero Casado Dependientes     Education Autoempleado  Ingresos  \
# 190    Male     No            0  Not Graduate           No      4885
# 388    Male    Yes            0      Graduate           No      2333
# 350    Male    Yes            0      Graduate           No      9083
# 421  Female     No            0  Not Graduate           No      2720
# 172    Male    Yes           3+  Not Graduate           No      3522
# ..      ...    ...          ...           ...          ...       ...
# 237  Female     No            0      Graduate          Yes      3463
# 31     Male     No            0      Graduate           No      3167
# 488    Male    Yes            2      Graduate          Yes      4583
# 40     Male     No            0      Graduate           No      3600
# 595    Male     No            0  Not Graduate           No      3833
#
#      Ingresos_cosolicitante  Monto  Monto_plazo  credito  Propiedad
# 190                     0.0   48.0        360.0      1.0      Rural
# ...

# %%
X_train['Dependientes'].value_counts(dropna=False)
# Out:
# 0      281
# 1       81
# 2       79
# 3+      40
# NaN     10
# Name: Dependientes, dtype: int64

# %%
diccionario = {'0': 0, '1': 1, '2': 2, '3+': 3}
X_train['Dependientes'] = X_train['Dependientes'].map(diccionario)
# Out:
# C:\Users\CARLOS\AppData\Local\Temp/ipykernel_14540/3847020335.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
X_train['Dependientes'].value_counts(dropna = False)
# Out:
# 0.0    281
# 1.0     81
# 2.0     79
# 3.0     40
# NaN     10
# Name: Dependientes, dtype: int64

# %%
X_train
# Out:
#      Genero Casado  Dependientes     Education Autoempleado  Ingresos  \
# 190    Male     No           0.0  Not Graduate           No      4885
# 388    Male    Yes           0.0      Graduate           No      2333
# 350    Male    Yes           0.0      Graduate           No      9083
# 421  Female     No           0.0  Not Graduate           No      2720
# 172    Male    Yes           3.0  Not Graduate           No      3522
# ..      ...    ...           ...           ...          ...       ...
# 237  Female     No           0.0      Graduate          Yes      3463
# 31     Male     No           0.0      Graduate           No      3167
# 488    Male    Yes           2.0      Graduate          Yes      4583
# 40     Male     No           0.0      Graduate           No      3600
# 595    Male     No           0.0  Not Graduate           No      3833
#
#      Ingresos_cosolicitante  Monto  Monto_plazo  credito  Propiedad
# ...

# %% [markdown]
# #### Datos Faltantes

# %%
df.isnull().sum()
# Out:
# Genero                    13
# Casado                     3
# Dependientes              15
# Education                  0
# Autoempleado              32
# Ingresos                   0
# Ingresos_cosolicitante     0
# Monto                     22
# Monto_plazo               14
# credito                   50
# Propiedad                  0
# Target                     0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 12 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Genero                  601 non-null    object
#  1   Casado                  611 non-null    object
#  2   Dependientes            599 non-null    object
#  3   Education               614 non-null    object
#  4   Autoempleado            582 non-null    object
#  5   Ingresos                614 non-null    int64
#  6   Ingresos_cosolicitante  614 non-null    float64
#  7   Monto                   592 non-null    float64
#  8   Monto_plazo             600 non-null    float64
#  9   credito                 564 non-null    float64
#  10  Propiedad               614 non-null    object
#  11  Target                  614 non-null    int64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 57.7+ KB

# %%
# !pip install missingno
import missingno as msno

# %%
msno.matrix(X_train)
plt.show()

# %%
def valores_nulos(df): 
        mis_val = df.isnull().sum()
        mis_val_percent = 100 * df.isnull().sum() / len(df)
        mis_val_table = pd.concat([mis_val, mis_val_percent], axis=1)
        mis_val_table_ren_columns = mis_val_table.rename(
        columns = {0 : 'Missing Values', 1 : '% of Total Values'})
        mis_val_table_ren_columns = mis_val_table_ren_columns[
            mis_val_table_ren_columns.iloc[:,1] != 0].sort_values(
        '% of Total Values', ascending=False).round(1)
        print ("Your selected dataframe has " + str(df.shape[1]) + " columns.\n"      
            "There are " + str(mis_val_table_ren_columns.shape[0]) +
              " columns that have missing values.")
        return mis_val_table_ren_columns

# %%
valores_nulos(X_train)
# Out:
# Your selected dataframe has 11 columns.
# There are 7 columns that have missing values.
#               Missing Values  % of Total Values
# credito                   39                7.9
# Autoempleado              25                5.1
# Monto                     15                3.1
# Genero                    11                2.2
# Dependientes              10                2.0
# Monto_plazo                5                1.0
# Casado                     1                0.2

# %% [markdown]
# #### Deteccón de outliers

# %%
def porcentaje_outlier(data, columna):
    rango_intercuartil = data[columna].quantile(.75)- data[columna].quantile(.25)
    limite_superior = data[columna].quantile(.75) + 1.5*rango_intercuartil
    limite_inferior = data[columna].quantile(.25) - 1.5*rango_intercuartil
    #print('Rango superior: ',limite_superior)
    #print('Rango inferior: ',limite_inferior)
    outliers_count = data[(data[columna]>limite_superior)|(data[columna]<limite_inferior)].shape[0]
    print('Porcentaje de outliers en',columna,': ',np.round(outliers_count*100/data.shape[0],2),'%')
    #return limite_superior,limite_inferior, np.round(outliers_count*100/data.shape[0],2)

# %%
porcentaje_outlier(X_train, 'Ingresos')
# Out:
# Porcentaje de outliers en Ingresos :  8.15 %

# %%
columnas = list(X_train.columns)
columnas
# Out:
# ['Genero',
#  'Casado',
#  'Dependientes',
#  'Education',
#  'Autoempleado',
#  'Ingresos',
#  'Ingresos_cosolicitante',
#  'Monto',
#  'Monto_plazo',
#  'credito',
#  'Propiedad']

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14540/28568862.py in <module>
#       1 for columna in columnas:
# ----> 2     print('columna',porcentaje_outlier(X_train, columna),'')
#
# ~\AppData\Local\Temp/ipykernel_14540/3067342097.py in porcentaje_outlier(data, columna)
#       1 def porcentaje_outlier(data, columna):
# ----> 2     rango_intercuartil = data[columna].quantile(.75)- data[columna].quantile(.25)
#       3     limite_superior = data[columna].quantile(.75) + 1.5*rango_intercuartil
#       4     limite_inferior = data[columna].quantile(.25) - 1.5*rango_intercuartil
#       5     #print('Rango superior: ',limite_superior)
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in quantile(self, q, interpolation)
#    2446         df = self.to_frame()
#    2447
# ...

# %% [markdown]
# #### Transformaciones
